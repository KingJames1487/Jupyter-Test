# %%
import numpy as np
import sys

# %%
def print_array(array):
    print(array)

# %%
b = np.ones(3)

print_array(b)
# Out:
# [1. 1. 1.]

# %% [markdown]
# # Test Heading
#
# ## Another Test Heading
#
# This is just normal text, but you may also make it **bold** or *italic*.
#
# * Lists are done like this
# 1. And can be numbered
# 2. Like this
#
# [Here is a hyperlink](https://www.example.com)
#
# And here is some `inline_code()` as well as how to do code blocks
#
#     code(block):
#         return block
#
# Or like this
# ```
# a_different_code(block):
#     return code(block)
# ```
#
# And here are images (Note, this is not a real image so it won't work): ![Alt text](https://www.example.com/image.jpg)
